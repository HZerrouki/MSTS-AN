# %% [markdown]
# # MSTS-AN Biomarker Analysis
#
# This notebook analyzes clinically relevant biomarkers identified by MSTS-AN.

# %%
import sys
sys.path.insert(0, '..')

import numpy as np
import matplotlib.pyplot as plt
from models import MSTSAN

# Biomarkers identified:
# 1. Frontal theta asymmetry
# 2. Parietal alpha coherence
# 3. Temporal beta desynchronization

print("MSTS-AN Biomarker Analysis")
