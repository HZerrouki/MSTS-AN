# %% [markdown]
# # MSTS-AN Model Visualization
#
# This notebook explores the MSTS-AN model architecture.

# %%
import sys
sys.path.insert(0, '..')

import torch
from models import MSTSAN

# Create model
model = MSTSAN(
    n_channels=19,
    seq_length=1024,
    n_bands=4,
    n_classes=3
)

print(model)
print(f"\nTotal parameters: {sum(p.numel() for p in model.parameters()):,}")
